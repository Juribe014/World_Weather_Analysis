# %%
# Import the random module.
import random

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=2000)
# Out:
# 18.1 µs ± 1.18 µs per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-500, 500) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(2000)
# Out:
# 1.98 ms ± 179 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
#coordinates

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 620

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        for i in city_weather['weather']:
            city_description=i["description"]        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | harper
# Processing Record 5 of Set 1 | linqing
# Processing Record 6 of Set 1 | tuatapere
# Processing Record 7 of Set 1 | itarema
# Processing Record 8 of Set 1 | bulzesti
# Processing Record 9 of Set 1 | berlevag
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | tshane
# Processing Record 13 of Set 1 | stefanesti
# Processing Record 14 of Set 1 | nhulunbuy
# Processing Record 15 of Set 1 | ambilobe
# Processing Record 16 of Set 1 | ixtapa
# Processing Record 17 of Set 1 | rumonge
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | livingston
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | vila velha
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | iqaluit
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | mayo
# Processing Record 27 of Set 1 | mukhanovo
# City not found. Skipping...
# Processing Record 28 of Set 1 | codrington
# Processing Record 29 of Set 1 | mantua
# Processing Record 30 of Set 1 | palmer
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 1 | north bend
# Processing Record 37 of Set 1 | walvis bay
# Processing Record 38 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | singaraja
# Processing Record 41 of Set 1 | mehamn
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | port elizabeth
# Processing Record 44 of Set 1 | bambous virieux
# Processing Record 45 of Set 1 | naze
# Processing Record 46 of Set 1 | lebu
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | te anau
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | severo-kurilsk
# Processing Record 4 of Set 2 | fort nelson
# Processing Record 5 of Set 2 | nyurba
# Processing Record 6 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 2 | kudahuvadhoo
# Processing Record 8 of Set 2 | jardim
# Processing Record 9 of Set 2 | marrakesh
# Processing Record 10 of Set 2 | georgetown
# Processing Record 11 of Set 2 | roma
# Processing Record 12 of Set 2 | castro
# Processing Record 13 of Set 2 | pevek
# Processing Record 14 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | altay
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | tono
# Processing Record 19 of Set 2 | san angelo
# Processing Record 20 of Set 2 | saint-leu
# Processing Record 21 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 22 of Set 2 | sao filipe
# Processing Record 23 of Set 2 | chuy
# Processing Record 24 of Set 2 | goderich
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | carnarvon
# Processing Record 27 of Set 2 | grindavik
# Processing Record 28 of Set 2 | porto novo
# Processing Record 29 of Set 2 | cidreira
# Processing Record 30 of Set 2 | butaritari
# Processing Record 31 of Set 2 | maralal
# Processing Record 32 of Set 2 | ponnampet
# Processing Record 33 of Set 2 | digha
# Processing Record 34 of Set 2 | bubaque
# Processing Record 35 of Set 2 | coquimbo
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | mount isa
# Processing Record 38 of Set 2 | asau
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 2 | valdivia
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | fortuna
# Processing Record 44 of Set 2 | mitchell
# Processing Record 45 of Set 2 | koungou
# Processing Record 46 of Set 2 | kralendijk
# Processing Record 47 of Set 2 | novaya ladoga
# Processing Record 48 of Set 2 | flinders
# Processing Record 49 of Set 2 | vidisha
# Processing Record 50 of Set 2 | tiksi
# Processing Record 1 of Set 3 | nome
# Processing Record 2 of Set 3 | ponta delgada
# Processing Record 3 of Set 3 | chegdomyn
# Processing Record 4 of Set 3 | derzhavinsk
# Processing Record 5 of Set 3 | santo antonio do ica
# Processing Record 6 of Set 3 | alofi
# Processing Record 7 of Set 3 | sitka
# Processing Record 8 of Set 3 | tasiilaq
# Processing Record 9 of Set 3 | smithers
# Processing Record 10 of Set 3 | saskylakh
# Processing Record 11 of Set 3 | baykit
# Processing Record 12 of Set 3 | gunjur
# Processing Record 13 of Set 3 | saint-francois
# Processing Record 14 of Set 3 | sirawai
# Processing Record 15 of Set 3 | vila franca do campo
# Processing Record 16 of Set 3 | barrow
# Processing Record 17 of Set 3 | caohai
# Processing Record 18 of Set 3 | saryozek
# Processing Record 19 of Set 3 | constitucion
# Processing Record 20 of Set 3 | ituporanga
# Processing Record 21 of Set 3 | gillette
# Processing Record 22 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 3 | quatre cocos
# Processing Record 24 of Set 3 | hithadhoo
# Processing Record 25 of Set 3 | araouane
# Processing Record 26 of Set 3 | palu
# Processing Record 27 of Set 3 | hobyo
# Processing Record 28 of Set 3 | ciras
# City not found. Skipping...
# Processing Record 29 of Set 3 | san pedro
# Processing Record 30 of Set 3 | aklavik
# Processing Record 31 of Set 3 | itapipoca
# Processing Record 32 of Set 3 | kargil
# Processing Record 33 of Set 3 | nieves
# Processing Record 34 of Set 3 | kaa-khem
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | jamestown
# Processing Record 37 of Set 3 | makakilo city
# Processing Record 38 of Set 3 | kavieng
# Processing Record 39 of Set 3 | kyabe
# Processing Record 40 of Set 3 | la paz
# Processing Record 41 of Set 3 | souillac
# Processing Record 42 of Set 3 | pisco
# Processing Record 43 of Set 3 | upata
# Processing Record 44 of Set 3 | klaksvik
# Processing Record 45 of Set 3 | faanui
# Processing Record 46 of Set 3 | brunswick
# Processing Record 47 of Set 3 | severobaykalsk
# Processing Record 48 of Set 3 | batagay-alyta
# Processing Record 49 of Set 3 | cherdyn
# Processing Record 50 of Set 3 | bad worishofen
# Processing Record 1 of Set 4 | dwarka
# Processing Record 2 of Set 4 | severnyy
# Processing Record 3 of Set 4 | saint-philippe
# Processing Record 4 of Set 4 | clyde river
# Processing Record 5 of Set 4 | bethel
# Processing Record 6 of Set 4 | lamar
# Processing Record 7 of Set 4 | bati
# Processing Record 8 of Set 4 | mamou
# Processing Record 9 of Set 4 | watertown
# Processing Record 10 of Set 4 | nikolskoye
# Processing Record 11 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 4 | dolores
# Processing Record 13 of Set 4 | bhalki
# Processing Record 14 of Set 4 | geraldton
# Processing Record 15 of Set 4 | limbang
# Processing Record 16 of Set 4 | dukat
# Processing Record 17 of Set 4 | lermontovka
# Processing Record 18 of Set 4 | taltal
# Processing Record 19 of Set 4 | melville
# Processing Record 20 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 4 | lompoc
# Processing Record 22 of Set 4 | padang
# Processing Record 23 of Set 4 | inta
# Processing Record 24 of Set 4 | fort saint james
# Processing Record 25 of Set 4 | kibala
# Processing Record 26 of Set 4 | khatanga
# Processing Record 27 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 28 of Set 4 | sur
# Processing Record 29 of Set 4 | kaitangata
# Processing Record 30 of Set 4 | alihe
# Processing Record 31 of Set 4 | saint-georges
# Processing Record 32 of Set 4 | touros
# Processing Record 33 of Set 4 | pravia
# Processing Record 34 of Set 4 | panormos
# Processing Record 35 of Set 4 | juneau
# Processing Record 36 of Set 4 | mbandaka
# Processing Record 37 of Set 4 | ponta do sol
# Processing Record 38 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 4 | oussouye
# Processing Record 41 of Set 4 | umm kaddadah
# Processing Record 42 of Set 4 | komsomolskiy
# Processing Record 43 of Set 4 | chokurdakh
# Processing Record 44 of Set 4 | camacha
# Processing Record 45 of Set 4 | najran
# Processing Record 46 of Set 4 | guinticgan
# Processing Record 47 of Set 4 | moron
# Processing Record 48 of Set 4 | hasaki
# Processing Record 49 of Set 4 | maceio
# Processing Record 50 of Set 4 | bawku
# Processing Record 1 of Set 5 | timra
# Processing Record 2 of Set 5 | olafsvik
# Processing Record 3 of Set 5 | karatuzskoye
# Processing Record 4 of Set 5 | fountain
# Processing Record 5 of Set 5 | thompson
# Processing Record 6 of Set 5 | aswan
# Processing Record 7 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 5 | gura teghii
# Processing Record 9 of Set 5 | vibo valentia
# Processing Record 10 of Set 5 | huarmey
# Processing Record 11 of Set 5 | provideniya
# Processing Record 12 of Set 5 | luderitz
# Processing Record 13 of Set 5 | motril
# Processing Record 14 of Set 5 | mariental
# Processing Record 15 of Set 5 | hofn
# Processing Record 16 of Set 5 | sioux lookout
# Processing Record 17 of Set 5 | mangan
# Processing Record 18 of Set 5 | agadez
# Processing Record 19 of Set 5 | serpa
# Processing Record 20 of Set 5 | empalme
# Processing Record 21 of Set 5 | osmena
# Processing Record 22 of Set 5 | lagoa
# Processing Record 23 of Set 5 | los llanos de aridane
# Processing Record 24 of Set 5 | havoysund
# Processing Record 25 of Set 5 | airai
# Processing Record 26 of Set 5 | nishihara
# Processing Record 27 of Set 5 | chumikan
# Processing Record 28 of Set 5 | merauke
# Processing Record 29 of Set 5 | pathein
# Processing Record 30 of Set 5 | mae sai
# Processing Record 31 of Set 5 | eha amufu
# Processing Record 32 of Set 5 | ancud
# Processing Record 33 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 34 of Set 5 | namatanai
# Processing Record 35 of Set 5 | muisne
# Processing Record 36 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 37 of Set 5 | palana
# Processing Record 38 of Set 5 | kruisfontein
# Processing Record 39 of Set 5 | saint george
# Processing Record 40 of Set 5 | yulara
# Processing Record 41 of Set 5 | meulaboh
# Processing Record 42 of Set 5 | san patricio
# Processing Record 43 of Set 5 | fairbanks
# Processing Record 44 of Set 5 | labuhan
# Processing Record 45 of Set 5 | simao
# Processing Record 46 of Set 5 | acapulco
# Processing Record 47 of Set 5 | anshun
# Processing Record 48 of Set 5 | paso de los toros
# Processing Record 49 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 5 | kapit
# Processing Record 1 of Set 6 | canguaretama
# Processing Record 2 of Set 6 | traverse city
# Processing Record 3 of Set 6 | katsuura
# Processing Record 4 of Set 6 | pichayevo
# Processing Record 5 of Set 6 | noyabrsk
# Processing Record 6 of Set 6 | avera
# Processing Record 7 of Set 6 | mirpur sakro
# Processing Record 8 of Set 6 | norman wells
# Processing Record 9 of Set 6 | yeppoon
# Processing Record 10 of Set 6 | annau
# Processing Record 11 of Set 6 | muros
# Processing Record 12 of Set 6 | monteagudo
# Processing Record 13 of Set 6 | nantucket
# Processing Record 14 of Set 6 | takoradi
# Processing Record 15 of Set 6 | okhotsk
# Processing Record 16 of Set 6 | kissidougou
# Processing Record 17 of Set 6 | guiratinga
# Processing Record 18 of Set 6 | gurgan
# City not found. Skipping...
# Processing Record 19 of Set 6 | vila
# Processing Record 20 of Set 6 | bonthe
# Processing Record 21 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 6 | lamin
# Processing Record 23 of Set 6 | dumai
# Processing Record 24 of Set 6 | ca mau
# Processing Record 25 of Set 6 | xiongshi
# City not found. Skipping...
# Processing Record 26 of Set 6 | jinka
# Processing Record 27 of Set 6 | kozan
# Processing Record 28 of Set 6 | yerbogachen
# Processing Record 29 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 6 | samfya
# Processing Record 31 of Set 6 | pimentel
# Processing Record 32 of Set 6 | anloga
# Processing Record 33 of Set 6 | grand gaube
# Processing Record 34 of Set 6 | little current
# Processing Record 35 of Set 6 | shimoda
# Processing Record 36 of Set 6 | ribeira grande
# Processing Record 37 of Set 6 | petatlan
# Processing Record 38 of Set 6 | dekoa
# City not found. Skipping...
# Processing Record 39 of Set 6 | vanimo
# Processing Record 40 of Set 6 | sambava
# Processing Record 41 of Set 6 | buin
# Processing Record 42 of Set 6 | lakes entrance
# Processing Record 43 of Set 6 | kirakira
# Processing Record 44 of Set 6 | cayenne
# Processing Record 45 of Set 6 | esperance
# Processing Record 46 of Set 6 | longyearbyen
# Processing Record 47 of Set 6 | ambulu
# Processing Record 48 of Set 6 | namwala
# Processing Record 49 of Set 6 | bilibino
# Processing Record 50 of Set 6 | hvide sande
# Processing Record 1 of Set 7 | dunedin
# Processing Record 2 of Set 7 | siuna
# Processing Record 3 of Set 7 | omboue
# Processing Record 4 of Set 7 | nagyszenas
# Processing Record 5 of Set 7 | seydi
# Processing Record 6 of Set 7 | ust-karsk
# Processing Record 7 of Set 7 | maputo
# Processing Record 8 of Set 7 | wanning
# Processing Record 9 of Set 7 | sibu
# Processing Record 10 of Set 7 | tamluk
# Processing Record 11 of Set 7 | nanortalik
# Processing Record 12 of Set 7 | wewak
# Processing Record 13 of Set 7 | port lincoln
# Processing Record 14 of Set 7 | nador
# Processing Record 15 of Set 7 | veraval
# Processing Record 16 of Set 7 | mahebourg
# Processing Record 17 of Set 7 | cockburn town
# Processing Record 18 of Set 7 | san quintin
# Processing Record 19 of Set 7 | sinnamary
# Processing Record 20 of Set 7 | lensk
# Processing Record 21 of Set 7 | egvekinot
# Processing Record 22 of Set 7 | coihaique
# Processing Record 23 of Set 7 | atambua
# Processing Record 24 of Set 7 | isla vista
# Processing Record 25 of Set 7 | yaan
# Processing Record 26 of Set 7 | fare
# Processing Record 27 of Set 7 | novikovo
# Processing Record 28 of Set 7 | batticaloa
# Processing Record 29 of Set 7 | isangel
# Processing Record 30 of Set 7 | forest
# Processing Record 31 of Set 7 | cravo norte
# Processing Record 32 of Set 7 | kamina
# Processing Record 33 of Set 7 | lorengau
# Processing Record 34 of Set 7 | pacific grove
# Processing Record 35 of Set 7 | spassk
# Processing Record 36 of Set 7 | bowen
# Processing Record 37 of Set 7 | cabo san lucas
# Processing Record 38 of Set 7 | luwuk
# Processing Record 39 of Set 7 | aksay
# Processing Record 40 of Set 7 | san-pedro
# Processing Record 41 of Set 7 | riwaka
# Processing Record 42 of Set 7 | tura
# Processing Record 43 of Set 7 | tanout
# Processing Record 44 of Set 7 | yuscaran
# Processing Record 45 of Set 7 | talnakh
# Processing Record 46 of Set 7 | gari
# Processing Record 47 of Set 7 | zverinogolovskoye
# Processing Record 48 of Set 7 | sharlyk
# Processing Record 49 of Set 7 | sumkino
# Processing Record 50 of Set 7 | lyubech
# Processing Record 1 of Set 8 | umm lajj
# Processing Record 2 of Set 8 | tiarei
# Processing Record 3 of Set 8 | tyup
# Processing Record 4 of Set 8 | kon tum
# Processing Record 5 of Set 8 | huanren
# Processing Record 6 of Set 8 | khash
# Processing Record 7 of Set 8 | springbok
# Processing Record 8 of Set 8 | mar del plata
# Processing Record 9 of Set 8 | male
# Processing Record 10 of Set 8 | whitehorse
# Processing Record 11 of Set 8 | puerto narino
# Processing Record 12 of Set 8 | pleshanovo
# Processing Record 13 of Set 8 | zhangye
# Processing Record 14 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 8 | tucurui
# Processing Record 16 of Set 8 | kieta
# Processing Record 17 of Set 8 | boyolangu
# Processing Record 18 of Set 8 | gaeta
# Processing Record 19 of Set 8 | ylivieska
# Processing Record 20 of Set 8 | hwange
# Processing Record 21 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 8 | ajaccio
# Processing Record 23 of Set 8 | barranca
# Processing Record 24 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 8 | ocos
# Processing Record 26 of Set 8 | casper
# Processing Record 27 of Set 8 | hamilton
# Processing Record 28 of Set 8 | san andres
# Processing Record 29 of Set 8 | rio cauto
# Processing Record 30 of Set 8 | dneprovskaya
# Processing Record 31 of Set 8 | chulman
# Processing Record 32 of Set 8 | laguna
# Processing Record 33 of Set 8 | mandan
# Processing Record 34 of Set 8 | muroto
# Processing Record 35 of Set 8 | cap malheureux
# Processing Record 36 of Set 8 | slochteren
# Processing Record 37 of Set 8 | ofaqim
# Processing Record 38 of Set 8 | awjilah
# Processing Record 39 of Set 8 | sovetskiy
# Processing Record 40 of Set 8 | waiouru
# Processing Record 41 of Set 8 | aiken
# Processing Record 42 of Set 8 | anadyr
# Processing Record 43 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 8 | bardiyah
# Processing Record 45 of Set 8 | san cristobal
# Processing Record 46 of Set 8 | rapid city
# Processing Record 47 of Set 8 | yar-sale
# Processing Record 48 of Set 8 | ilulissat
# Processing Record 49 of Set 8 | port augusta
# Processing Record 50 of Set 8 | amapa
# Processing Record 1 of Set 9 | rock hill
# Processing Record 2 of Set 9 | macusani
# Processing Record 3 of Set 9 | voh
# Processing Record 4 of Set 9 | dingle
# Processing Record 5 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 9 | dubbo
# Processing Record 7 of Set 9 | atbasar
# Processing Record 8 of Set 9 | pallikonda
# City not found. Skipping...
# Processing Record 9 of Set 9 | kharp
# Processing Record 10 of Set 9 | nuuk
# Processing Record 11 of Set 9 | derbent
# Processing Record 12 of Set 9 | saint-augustin
# Processing Record 13 of Set 9 | aksarka
# Processing Record 14 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 9 | rudsar
# Processing Record 16 of Set 9 | deputatskiy
# Processing Record 17 of Set 9 | dikson
# Processing Record 18 of Set 9 | khokhlovo
# Processing Record 19 of Set 9 | ostrovnoy
# Processing Record 20 of Set 9 | virginia beach
# Processing Record 21 of Set 9 | san felipe
# Processing Record 22 of Set 9 | westport
# Processing Record 23 of Set 9 | salalah
# Processing Record 24 of Set 9 | guerrero negro
# Processing Record 25 of Set 9 | srednekolymsk
# Processing Record 26 of Set 9 | ometepec
# Processing Record 27 of Set 9 | beloha
# Processing Record 28 of Set 9 | nalut
# Processing Record 29 of Set 9 | santa cruz
# Processing Record 30 of Set 9 | bend
# Processing Record 31 of Set 9 | angicos
# Processing Record 32 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 9 | sechura
# Processing Record 34 of Set 9 | bima
# Processing Record 35 of Set 9 | drjanovo
# City not found. Skipping...
# Processing Record 36 of Set 9 | henties bay
# Processing Record 37 of Set 9 | saint-joseph
# Processing Record 38 of Set 9 | jerez
# Processing Record 39 of Set 9 | chapada dos guimaraes
# Processing Record 40 of Set 9 | kahului
# Processing Record 41 of Set 9 | lieto
# Processing Record 42 of Set 9 | viedma
# Processing Record 43 of Set 9 | kargat
# Processing Record 44 of Set 9 | surt
# Processing Record 45 of Set 9 | pozo colorado
# Processing Record 46 of Set 9 | alexandria
# Processing Record 47 of Set 9 | velsk
# Processing Record 48 of Set 9 | reyes
# Processing Record 49 of Set 9 | rovaniemi
# Processing Record 50 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 10 | nouadhibou
# Processing Record 2 of Set 10 | ahipara
# Processing Record 3 of Set 10 | lata
# Processing Record 4 of Set 10 | nizhniy odes
# Processing Record 5 of Set 10 | staritsa
# Processing Record 6 of Set 10 | saint anthony
# Processing Record 7 of Set 10 | msanga
# Processing Record 8 of Set 10 | hualmay
# Processing Record 9 of Set 10 | accra
# Processing Record 10 of Set 10 | bahawalnagar
# Processing Record 11 of Set 10 | luanda
# Processing Record 12 of Set 10 | rabaul
# Processing Record 13 of Set 10 | santa ines
# Processing Record 14 of Set 10 | lasa
# Processing Record 15 of Set 10 | dubenskiy
# City not found. Skipping...
# Processing Record 16 of Set 10 | mitu
# Processing Record 17 of Set 10 | yarada
# Processing Record 18 of Set 10 | beaverlodge
# Processing Record 19 of Set 10 | azangaro
# Processing Record 20 of Set 10 | gorom-gorom
# Processing Record 21 of Set 10 | high rock
# Processing Record 22 of Set 10 | ketchikan
# Processing Record 23 of Set 10 | nizwa
# Processing Record 24 of Set 10 | san policarpo
# Processing Record 25 of Set 10 | la ronge
# Processing Record 26 of Set 10 | sept-iles
# Processing Record 27 of Set 10 | tombouctou
# Processing Record 28 of Set 10 | rio gallegos
# Processing Record 29 of Set 10 | huntsville
# Processing Record 30 of Set 10 | pacifica
# Processing Record 31 of Set 10 | kavaratti
# Processing Record 32 of Set 10 | torbay
# Processing Record 33 of Set 10 | rosarito
# Processing Record 34 of Set 10 | erenhot
# Processing Record 35 of Set 10 | victoria
# Processing Record 36 of Set 10 | yashkul
# Processing Record 37 of Set 10 | yakovlevo
# Processing Record 38 of Set 10 | ouallam
# Processing Record 39 of Set 10 | severomorsk
# Processing Record 40 of Set 10 | montes altos
# Processing Record 41 of Set 10 | sistranda
# Processing Record 42 of Set 10 | la asuncion
# Processing Record 43 of Set 10 | comodoro rivadavia
# Processing Record 44 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 10 | bichena
# Processing Record 46 of Set 10 | sheridan
# Processing Record 47 of Set 10 | harbour breton
# Processing Record 48 of Set 10 | litovko
# Processing Record 49 of Set 10 | pangnirtung
# Processing Record 50 of Set 10 | nanakuli
# Processing Record 1 of Set 11 | adeje
# Processing Record 2 of Set 11 | halifax
# Processing Record 3 of Set 11 | kondinskoye
# Processing Record 4 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 5 of Set 11 | parati
# Processing Record 6 of Set 11 | sault sainte marie
# Processing Record 7 of Set 11 | ariquemes
# Processing Record 8 of Set 11 | husavik
# Processing Record 9 of Set 11 | finschhafen
# Processing Record 10 of Set 11 | carutapera
# Processing Record 11 of Set 11 | araguaina
# Processing Record 12 of Set 11 | vestmannaeyjar
# Processing Record 13 of Set 11 | lagos
# Processing Record 14 of Set 11 | kumluca
# Processing Record 15 of Set 11 | stephenville
# Processing Record 16 of Set 11 | san luis
# Processing Record 17 of Set 11 | fort-shevchenko
# Processing Record 18 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 11 | boa vista
# Processing Record 21 of Set 11 | ayan
# Processing Record 22 of Set 11 | olyka
# Processing Record 23 of Set 11 | adre
# Processing Record 24 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 11 | alenquer
# Processing Record 26 of Set 11 | karasjok
# Processing Record 27 of Set 11 | karratha
# Processing Record 28 of Set 11 | nakambala
# Processing Record 29 of Set 11 | napoleon
# Processing Record 30 of Set 11 | nizhniy kuranakh
# Processing Record 31 of Set 11 | lephepe
# City not found. Skipping...
# Processing Record 32 of Set 11 | colares
# Processing Record 33 of Set 11 | concordia
# Processing Record 34 of Set 11 | hambantota
# Processing Record 35 of Set 11 | ciudad bolivar
# Processing Record 36 of Set 11 | half moon bay
# Processing Record 37 of Set 11 | carmelo
# Processing Record 38 of Set 11 | birao
# Processing Record 39 of Set 11 | erzin
# Processing Record 40 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 11 | lakhnadon
# Processing Record 42 of Set 11 | vernon
# Processing Record 43 of Set 11 | bathurst
# Processing Record 44 of Set 11 | margate
# Processing Record 45 of Set 11 | kuryk
# Processing Record 46 of Set 11 | waipawa
# Processing Record 47 of Set 11 | ulagan
# Processing Record 48 of Set 11 | guipavas
# Processing Record 49 of Set 11 | shahpura
# Processing Record 50 of Set 11 | damghan
# Processing Record 1 of Set 12 | nogliki
# Processing Record 2 of Set 12 | portland
# Processing Record 3 of Set 12 | broome
# Processing Record 4 of Set 12 | vallenar
# Processing Record 5 of Set 12 | katherine
# Processing Record 6 of Set 12 | kainantu
# Processing Record 7 of Set 12 | laviana
# Processing Record 8 of Set 12 | nabire
# Processing Record 9 of Set 12 | namie
# Processing Record 10 of Set 12 | chiang khong
# Processing Record 11 of Set 12 | dawson creek
# Processing Record 12 of Set 12 | redlands
# Processing Record 13 of Set 12 | bertoua
# Processing Record 14 of Set 12 | minuri
# Processing Record 15 of Set 12 | dezful
# Processing Record 16 of Set 12 | gamba
# Processing Record 17 of Set 12 | vao
# Processing Record 18 of Set 12 | saldanha
# Processing Record 19 of Set 12 | kawhia
# Processing Record 20 of Set 12 | tiznit
# Processing Record 21 of Set 12 | svetlogorsk
# Processing Record 22 of Set 12 | scalloway
# City not found. Skipping...
# Processing Record 23 of Set 12 | black river
# Processing Record 24 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 12 | bandiagara
# Processing Record 26 of Set 12 | hami
# Processing Record 27 of Set 12 | port hardy
# Processing Record 28 of Set 12 | flagstaff
# Processing Record 29 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 12 | dawei
# Processing Record 31 of Set 12 | riyadh
# Processing Record 32 of Set 12 | madinat sittah uktubar
# Processing Record 33 of Set 12 | kyra
# Processing Record 34 of Set 12 | lakselv
# Processing Record 35 of Set 12 | imbituba
# Processing Record 36 of Set 12 | santiago del estero
# Processing Record 37 of Set 12 | beringovskiy
# Processing Record 38 of Set 12 | jacqueville
# Processing Record 39 of Set 12 | tocopilla
# Processing Record 40 of Set 12 | ucluelet
# Processing Record 41 of Set 12 | dubinino
# Processing Record 42 of Set 12 | senador pompeu
# Processing Record 43 of Set 12 | monte cristi
# City not found. Skipping...
# Processing Record 44 of Set 12 | minervino murge
# Processing Record 45 of Set 12 | rio verde de mato grosso
# Processing Record 46 of Set 12 | mapimi
# Processing Record 47 of Set 12 | japura
# Processing Record 48 of Set 12 | pindwara
# Processing Record 49 of Set 12 | fredericksburg
# Processing Record 50 of Set 12 | dalbandin
# Processing Record 1 of Set 13 | tahoua
# Processing Record 2 of Set 13 | eureka
# Processing Record 3 of Set 13 | khandyga
# Processing Record 4 of Set 13 | thinadhoo
# Processing Record 5 of Set 13 | buraydah
# Processing Record 6 of Set 13 | faya
# Processing Record 7 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 13 | vardo
# Processing Record 9 of Set 13 | sujangarh
# Processing Record 10 of Set 13 | puerto carreno
# Processing Record 11 of Set 13 | chernyshevskiy
# Processing Record 12 of Set 13 | lerwick
# Processing Record 13 of Set 13 | momcilgrad
# City not found. Skipping...
# Processing Record 14 of Set 13 | kaspiyskiy
# Processing Record 15 of Set 13 | zhenhai
# Processing Record 16 of Set 13 | kushiro
# Processing Record 17 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 13 | santa maria
# Processing Record 19 of Set 13 | narasannapeta
# Processing Record 20 of Set 13 | sola
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kapaa      US  22.0752 -159.3190     84.52        66          40
# 1      Rikitea      PF -23.1203 -134.9692     70.52        69          58
# 2       Harper      LR   4.3750   -7.7169     75.58        87          42
# 3      Linqing      CN  36.8456  115.7117     67.73        65          96
# 4    Tuatapere      NZ -46.1333  167.6833     44.53        88          99
# 5      Itarema      BR  -2.9248  -39.9167     78.03        81          44
# 6     Bulzesti      RO  44.5333   23.8833     58.59        93         100
# 7     Berlevag      NO  70.8578   29.0864     42.80        93         100
# 8  East London      ZA -33.0153   27.9116     63.64        80         100
# 9      Mataura      NZ -46.1927  168.8643     43.52        96          99
#
#    Wind Speed              Description
# 0       13.80         scattered clouds
# 1       20.78            broken clouds
# 2        7.74         scattered clouds
# 3        6.46          overcast clouds
# 4       12.68          overcast clouds
# 5       18.37         scattered clouds
# 6        6.91               light rain
# 7       16.11  light intensity drizzle
# 8       15.61          overcast clouds
# 9        8.72               light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
